# %%
# unit matrix

A = np.array([[1,2],[3,4]])
I = np.eye(2)

print(A@I)
print(I@A)
# Out:
# [[1. 2.]
#  [3. 4.]]
# [[1. 2.]
#  [3. 4.]]

# %%
# matrix * vector

# %%
# linear combination of column vector

# %%
from sklearn.datasets import fetch_olivetti_faces

faces = fetch_olivetti_faces()

f, ax = plt.subplots(1,3)

ax[0].imshow(faces.images[6], cmap=plt.cm.bone)
ax[0].grid(False)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_title('image 1:$x_1$')

ax[1].imshow(faces.images[10], cmap=plt.cm.bone)
ax[1].grid(False)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_title('image 1:$x_2$')


new_face = 0.7 * faces.images[6] + 0.3 * faces.images[10]
ax[2].imshow(new_face, cmap=plt.cm.bone)
ax[2].grid(False)
ax[2].set_xticks([])
ax[2].set_yticks([])
ax[2].set_title('image 1:$0.7x_1$ + 0.3x_2$')

plt.show()

# %%
# concurrent operation for weighted sum of multi-vector

# %%
# residual

# %%
# resudual sum of squares
